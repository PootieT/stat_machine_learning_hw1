# %% [markdown]
# ## Homework 1: Part 2
# ## Implementing regularized linear regression
# In this part, you will implement regularized linear regression and use it to
# study models with different bias-variance properties.
#
# This notebook contains code that helps you get started on
# linear regression with regularization.
# You will need to complete functions in
# **reg_linear_regressor.py** and **utils.py**.
# Modify this notebook in places marked by **TODO:**.

# %% [markdown]
# ## Regularized linear regression: an example
# In this problem, you will implement regularized linear regression
# to predict the amount of water flowing out of a dam using the change
# of water level in a reservoir. We will begin by visualizing the dataset containing historical records on the
# change in the water level $x$, and the amount of water $y$, flowing out of the dam.
# This dataset is divided into three parts:
# - A training set that you will use to learn the model:  X,  y.
# - A validation set for determining the regularization parameter: Xval, yval.
# - A test set for evaluating the performance of your model:  Xtest, ytest. These are unseen examples that were not used during the training of the model.
#
# Run the cell below and it  will plot the training data as shown in Figure 6 in your assignment handout.

# %%
import numpy as np
import matplotlib.pyplot as plt
import utils
import plot_utils
from reg_linear_regressor_multi import RegularizedLinearReg_SquaredLoss
from sklearn.model_selection import train_test_split

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython

# %load_ext autoreload
# %autoreload 2

########################################################################
## =========== Part 1: Loading and Visualizing Data ===================#
########################################################################
# Load Training Data

print 'Loading and Visualizing Data ...'

X, y, Xtest, ytest, Xval, yval = utils.load_mat('ex2data1.mat')

# Plot training data

plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.show()
# Out:
# Loading and Visualizing Data ...

# %% [markdown]
# ## Regularized Linear Regression cost function and gradient (vectorized)
# You should now implement the loss function and gradient of the
# loss function for regularized linear regression in **reg_linear_regression_multi.py**. Then run the cell below.
# Regularized linear regression has the following cost function:
# $$J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right) + \frac{\lambda}{2m}\left( \sum_{j=1}^{n} {\theta_j}^2 \right) $$
# where $\lambda$ is a regularization parameter which controls the degree of regularization
# (thus, help preventing overfitting). The regularization term puts
# a penalty on the overall cost $J(\theta)$. As the magnitudes of the model parameters $\theta_j$ increase, the penalty increases as well. Note that you should not regularize the $\theta_0$ term. You should now complete the code for the method loss in the class Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py to calculate $J(\theta)$. Vectorize your code and avoid writing for loops.
#
# Correspondingly, the partial derivative of the regularized linear regression  cost function
# with respect to  $\theta_j$ is defined as:
# \begin{eqnarray*}
# \frac{\partial J(\theta)}{\partial \theta_0} & = & \frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)}){x_j}^{(i)} \\
# \frac{\partial J(\theta)}{\partial \theta_j} & = & \left(\frac{1}{m} \sum_{i=1}^{m} (h_\theta(x^{(i)}) - y^{(i)} ){x_j}^{(i)}\right) + \frac{\lambda}{m}{\theta_j} \; \; \; \mbox{ for }j \geq 1\\
# \end{eqnarray*}
# You should now complete the code for the method grad_loss in the class {Reg_LinearRegression_SquaredLoss in the file reg_linear_regressor_multi.py}
# to  calculate the gradient, returning
# it in the variable grad.
#
# Then evaluate the cell below. It runs the train method in  reg_linear_regressor_multi.py to compute the optimal value
# of $\theta$. This training function uses scipy's fmin_bfgs to optimize the cost function.
# Here we have set the regularization parameter $\lambda$ to zero.
#
# The best fit line plotted by the script  tells us that the model is
# not a good fit to the data because the data is non-linear. While
# visualizing the best fit as shown is one possible way to debug your learning
# algorithm, it is not always easy to visualize the data and model. In the next
# cell, you will implement a function to generate learning curves that can
# help you debug your learning algorithm even if it is not easy to visualize the
# data.

# %%
# append a column of ones to matrix X

XX = np.vstack([np.ones((X.shape[0],)),X]).T

#  Train linear regression with lambda = 0

reglinear_reg1 = RegularizedLinearReg_SquaredLoss()
theta_opt0 = reglinear_reg1.train(XX,y,reg=0.0,num_iters=1000)
print 'Theta at lambda = 0 is ', theta_opt0

# plot fit over data and show it (or save it in fig7.pdf)
plot_utils.plot_data(X,y,'Change in water level (x)','Water flowing out of the dam (y)')
plt.plot(X,np.dot(XX,theta_opt0),'g-',linewidth=3)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 22.373906
#          Iterations: 5
#          Function evaluations: 6
#          Gradient evaluations: 6
# Theta at lambda = 0 is  [13.08790353  0.36777923]

# %% [markdown]
# ## Learning curve for linear regression
# An important concept in machine learning is the bias-variance tradeoff. Models
# with high bias are not complex enough for the data and tend to underfit,
# while models with high variance overfit  the training data.
# Here you will plot training and test errors on a
# learning curve to diagnose bias-variance problems.
#
# A  learning curve plots
# training and cross validation error as a function of training set size. You will complete the
# function  learning_curve in utils.py so that it returns a vector of errors for the
# training set and  validation set.
# To obtain different training set sizes,
# use different subsets of the original training set X. Specifically, for
# a training set size of $i$, you should use the first $i$ examples.
#
# You can use the train function to find the parameter $\theta$. Note
# that the regularization $\lambda$  is passed as a parameter to the learning_curve function.
# After learning the $\theta$ parameter, you should compute the error on the training
# and validation sets. Recall that the training error for a dataset is
# defined as:
# $$ J(\theta) = \frac{1}{2m} \left( \sum_{i=1}^{m} {( y^{(i)} - h_\theta(x^{(i)})}^2\right)  $$
#
#
# In particular, note that the training error does not include the regularization
# term. One way to compute the training error is to use your existing
# cost function and set the regularization parameter reg to 0 only when using it to compute the training error
# and validation error. When you are computing the training set error,
# make sure you compute it on the training subset
# instead of the entire training set. However, for the validation error,
# you should compute it over the entire validation set. You should store
# the computed errors in the vectors error_train and error_val.
# When you are finished, the cell below will print the learning curves and produce
# a plot similar to Figure 8 in the assignment handout.

# %%
reg = 1.0
XXval = np.vstack([np.ones((Xval.shape[0],)),Xval]).T

# implement the learning_curve function in utils.py
# this script will run your function and show the learning curve

error_train, error_val = utils.learning_curve(XX,y,XXval,yval,reg)
plot_utils.plot_learning_curve(error_train, error_val,reg)
plt.show()
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.575589
#          Iterations: 2
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.499974
#          Iterations: 1
#          Function evaluations: 104
#          Gradient evaluations: 92
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 36.120098
#          Iterations: 2
#          Function evaluations: 96
#          Gradient evaluations: 84
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.203237
#          Iterations: 4
#          Function evaluations: 114
#          Gradient evaluations: 102
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 42.803055
#          Iterations: 3
#          Function evaluations: 105
#          Gradient evaluations: 93
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 39.232733
#          Iterations: 3
#          Function evaluations: 93
#          Gradient evaluations: 81
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34.650468
#          Iterations: 3
#          Function evaluations: 71
#          Gradient evaluations: 59
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.766806
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 98
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.957955
#          Iterations: 2
#          Function evaluations: 103
#          Gradient evaluations: 91
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.954649
#          Iterations: 2
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.323587
#          Iterations: 2
#          Function evaluations: 108
#          Gradient evaluations: 96
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.189591
#          Iterations: 2
#          Function evaluations: 99
#          Gradient evaluations: 87

# %% [markdown]
# ## Polynomial regression: expanding the basis functions
# The problem with our linear model was that it was too simple for the data
# and resulted in underfitting (high bias). In this problem, you will address this issue by adding more features. In particular, you will consider hypotheses of the form
# $$ h_\theta(x) = \theta_0 + \theta_1 x + \theta_2 x^2 + \ldots + \theta_p x^p $$
# This is still a linear model from the point of view of the parameter space. We have augmented the features with powers of $x$.
# Code in the cell below builds these features using sklearn's preprocessing module.
#
# We use a polynomial of degree 6.
# It turns out that if we run the training directly on the projected data,  it will
# not work well as the features would be badly scaled (e.g., an example with
# $x = 40$ will now have a feature $x^6 = 40^6 = 4.1 \times 10^{9}$). Therefore, you will
# need to use feature normalization.
# Before learning the parameter $\theta$ for the polynomial regression, the script in the cell below will
# first call the **feature_normalize** function you wrote earlier. It will normalize the features of the training set,
# storing the mu, sigma parameters separately. It will project the validation and test sets too, but normalize them using the same mu and sigma parameters.

# %%
from utils import feature_normalize
import sklearn
from sklearn.preprocessing import PolynomialFeatures

# Map X onto polynomial features and normalize
# We will consider a 6th order polynomial fit for the data

p = 6
poly = sklearn.preprocessing.PolynomialFeatures(degree=p,include_bias=False)
X_poly = poly.fit_transform(np.reshape(X,(len(X),1)))
X_poly, mu, sigma = utils.feature_normalize(X_poly)

# add a column of ones to X_poly

XX_poly = np.vstack([np.ones((X_poly.shape[0],)),X_poly.T]).T

# map Xtest and Xval into the same polynomial features

X_poly_test = poly.fit_transform(np.reshape(Xtest,(len(Xtest),1)))
X_poly_val = poly.fit_transform(np.reshape(Xval,(len(Xval),1)))

# normalize these two sets with the same mu and sigma

X_poly_test = (X_poly_test - mu) / sigma
X_poly_val = (X_poly_val - mu) / sigma

# add a column of ones to both X_poly_test and X_poly_val
XX_poly_test = np.vstack([np.ones((X_poly_test.shape[0],)),X_poly_test.T]).T
XX_poly_val = np.vstack([np.ones((X_poly_val.shape[0],)),X_poly_val.T]).T

# %% [markdown]
# ## Learning curves for polynomial regression
# The cell below trains a linear model on the transformed data. After learning $\theta$, you should see two plots
# generated for polynomial regression with $\lambda= 0$.

# %%
reg = 0
reglinear_reg2 = RegularizedLinearReg_SquaredLoss()
theta_opt1 = reglinear_reg1.train(XX_poly,y,reg=reg,num_iters=10000)
print 'Theta at lambda = 0 is ', theta_opt1


# plot data and training fit for the 6th order polynomial 

plot_utils.plot_fit(X,y,np.min(X),np.max(X),mu,sigma,theta_opt1,p,'Change in water level (x)','Water flowing out of dam (y)','Polynomial Regression fit with lambda = 0 and polynomial features of degree = ' + str(p))
plt.show()
# plot learning curve for data (6th order polynomail basis function) 

error_train,error_val = utils.learning_curve(XX_poly,y,XX_poly_val,yval,reg)
plot_utils.plot_learning_curve(error_train,error_val,reg)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45
# Theta at lambda = 0 is  [ 11.21758977  10.88676468  12.86207254  10.28506173  -4.20098901
#  -11.4141408   -4.90366713]
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 2
#          Function evaluations: 3
#          Gradient evaluations: 3
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 6
#          Function evaluations: 7
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 8
#          Function evaluations: 10
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 18
#          Function evaluations: 21
#          Gradient evaluations: 21
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 25
#          Function evaluations: 26
#          Gradient evaluations: 26
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 34
#          Function evaluations: 37
#          Gradient evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 48
#          Function evaluations: 50
#          Gradient evaluations: 50
# Optimization terminated successfully.
#          Current function value: 0.075859
#          Iterations: 48
#          Function evaluations: 49
#          Gradient evaluations: 49
# Optimization terminated successfully.
#          Current function value: 0.183744
#          Iterations: 45
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.224868
#          Iterations: 46
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.204675
#          Iterations: 46
#          Function evaluations: 47
#          Gradient evaluations: 47
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45

# %% [markdown]
# ## Adjusting the regularization parameter
# You will now explore how the regularization parameter
# affects the bias-variance of regularized polynomial regression. You should
# now modify the  lambda parameter in the cell above and try $\lambda = 1, 10, 100$. For
# each of these values, the script will generate a polynomial fit to the data
# and also a learning curve. Submit two plots for each value of lambda: the fit as well as the learning curve. Comment on the impact of the choice of lambda on the quality of the learned model in your **writeup.pdf**.

# %% [markdown]
# ## Calculating test error on the best model
# To get a better indication of a model's performance in the real
# world, it is important to evaluate the final model on a test set that was
# not used in any part of training (that is, it was neither used to select the regularization parameter, nor to learn the model parameters).
# Calculate the error of the best model that you found with the previous analysis
# and report it.

# %%
# TODO: your code for computing test error on the best model (model with the best lambda)
reglinear_reg2 = RegularizedLinearReg_SquaredLoss()
theta_opt1 = reglinear_reg1.train(XX_poly,y,reg=1,num_iters=10000)
reglinear_reg1.loss(theta_opt1,XX_poly_test,ytest,1.0)
# Out:
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.558946
#          Iterations: 7
#          Function evaluations: 118
#          Gradient evaluations: 106
# 9.432203518135317

# %% [markdown]
# ## Selecting $\lambda$ using a validation set
# You will implement an automated method to select the $\lambda$ parameter. Concretely, you will use a validation set to evaluate how good each $\lambda$ value is. After selecting the best $\lambda$ value using the
# validation set, we can then evaluate the model on the test set to estimate
# how well the model will perform on actual unseen data.
# **Complete the function validation_curve.m in utils.py**. Specifically,
# you should should use the train method on an instance of the class Reg_Linear_Regressor to train the model using
# different values of $\lambda$ and to compute the training error and  validation error.
# You should try $\lambda$ in the following range: \{0, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10\}.
#
# After you have completed the code, run the cell below to plot a validation curve of $\lambda$ versus the error. This plot  allows you select
# which $\lambda$ value to use. Due to randomness
# in the training and validation splits of the dataset, the cross validation error
# can sometimes be lower than the training error. Submit a pdf version of this plot in **writeup.pdf**. Comment on the best choice of $\lambda$ for this problem.

# %%
# now implement the validation_curve function in utils.py
# this function helps in determining the best lambda using a
# a validation set
# The code will now run your function and plot the figure 

reg_vec, error_train, error_val = utils.validation_curve(XX_poly,y,XX_poly_val,yval)
plot_utils.plot_lambda_selection(reg_vec,error_train,error_val)
plt.show()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198053
#          Iterations: 44
#          Function evaluations: 45
#          Gradient evaluations: 45
# Optimization terminated successfully.
#          Current function value: 0.225496
#          Iterations: 43
#          Function evaluations: 44
#          Gradient evaluations: 44
# Optimization terminated successfully.
#          Current function value: 0.275838
#          Iterations: 42
#          Function evaluations: 43
#          Gradient evaluations: 43
# Optimization terminated successfully.
#          Current function value: 0.430709
#          Iterations: 40
#          Function evaluations: 41
#          Gradient evaluations: 41
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.804545
#          Iterations: 37
#          Function evaluations: 106
#          Gradient evaluations: 94
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.897136
#          Iterations: 21
#          Function evaluations: 119
#          Gradient evaluations: 107
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.503742
#          Iterations: 18
#          Function evaluations: 115
#          Gradient evaluations: 103
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.558946
#          Iterations: 7
#          Function evaluations: 118
#          Gradient evaluations: 106
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28.220735
#          Iterations: 6
#          Function evaluations: 117
#          Gradient evaluations: 105
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 62.981885
#          Iterations: 4
#          Function evaluations: 113
#          Gradient evaluations: 101

# %% [markdown]
# ## Plotting learning curves with randomly selected examples
# In practice, especially for small training sets, when you plot learning curves
# to debug your algorithms, it is often helpful to average across multiple sets
# of randomly selected examples to determine the training error and
# validation error.
# Concretely, to determine the training error and cross validation error for
# $i$ examples, you should first randomly select $i$ examples from the training set
# and $i$ examples from the  validation set. You will then learn the model parameters using the randomly chosen training set and evaluate the parameters on the randomly chosen training set and validation set. The above
# steps should then be repeated multiple times (say 50) and the averaged error
# should be used to determine the training error and cross validation error for
# $i$ examples.
# Implement the above
# strategy for computing the learning curves. Complete the  function
# **learning_curve_averaged** in  **utils.py** to generate compute and generate this plot. Then evaluate the cell below.

# %%
# now implement the averaged learning curve function in utils.py
# The script runs your function, plots the curves and saves it in fig11.pdf
import warnings
warnings.filterwarnings("ignore")

reg = 1.0
error_train,error_val = utils.averaged_learning_curve(XX_poly,y,XX_poly_val,yval,reg)
plot_utils.plot_learning_curve(error_train,error_val,reg)
plt.show()
# Out:
# (2, 7) (2,) (2, 7) (2,)
# [10  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.490263
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# (2, 7) (2,) (2, 7) (2,)
# [ 9 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.442138
#          Iterations: 5
#          Function evaluations: 117
#          Gradient evaluations: 105
# (2, 7) (2,) (2, 7) (2,)
# [0 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.036737
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (2, 7) (2,) (2, 7) (2,)
# [0 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.134210
#          Iterations: 5
#          Function evaluations: 113
#          Gradient evaluations: 101
# (2, 7) (2,) (2, 7) (2,)
# [ 9 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.442138
#          Iterations: 5
#          Function evaluations: 117
#          Gradient evaluations: 105
# (2, 7) (2,) (2, 7) (2,)
# [1 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 48.914045
#          Iterations: 5
#          Function evaluations: 113
#          Gradient evaluations: 101
# (2, 7) (2,) (2, 7) (2,)
# [9 7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.210728
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 96
# (2, 7) (2,) (2, 7) (2,)
# [11  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.461270
#          Iterations: 3
#          Function evaluations: 115
#          Gradient evaluations: 103
# (2, 7) (2,) (2, 7) (2,)
# [3 8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49.220784
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (2, 7) (2,) (2, 7) (2,)
# [8 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.655741
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 96
# (2, 7) (2,) (2, 7) (2,)
# [8 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.843238
#          Iterations: 3
#          Function evaluations: 58
#          Gradient evaluations: 47
# (2, 7) (2,) (2, 7) (2,)
# [10  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.229384
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 98
# (2, 7) (2,) (2, 7) (2,)
# [ 9 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.442138
#          Iterations: 5
#          Function evaluations: 117
#          Gradient evaluations: 105
# (2, 7) (2,) (2, 7) (2,)
# [6 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.784224
#          Iterations: 2
#          Function evaluations: 113
#          Gradient evaluations: 101
# (2, 7) (2,) (2, 7) (2,)
# [9 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.637027
#          Iterations: 9
#          Function evaluations: 100
#          Gradient evaluations: 88
# (2, 7) (2,) (2, 7) (2,)
# [1 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.929819
#          Iterations: 5
#          Function evaluations: 119
#          Gradient evaluations: 107
# (2, 7) (2,) (2, 7) (2,)
# [10  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.702706
#          Iterations: 2
#          Function evaluations: 104
#          Gradient evaluations: 92
# (2, 7) (2,) (2, 7) (2,)
# [10  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.096879
#          Iterations: 4
#          Function evaluations: 97
#          Gradient evaluations: 85
# (2, 7) (2,) (2, 7) (2,)
# [3 8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 49.220784
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (2, 7) (2,) (2, 7) (2,)
# [ 5 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.702706
#          Iterations: 2
#          Function evaluations: 104
#          Gradient evaluations: 92
# (2, 7) (2,) (2, 7) (2,)
# [2 6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 45.417138
#          Iterations: 2
#          Function evaluations: 109
#          Gradient evaluations: 97
# (2, 7) (2,) (2, 7) (2,)
# [4 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.438547
#          Iterations: 9
#          Function evaluations: 99
#          Gradient evaluations: 87
# (2, 7)
#  (2,) (2, 7) (2,)
# [10  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44.172597
#          Iterations: 2
#          Function evaluations: 102
#          Gradient evaluations: 90
# (2, 7) (2,) (2, 7) (2,)
# [ 6 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 17.321235
#          Iterations: 3
#          Function evaluations: 105
#          Gradient evaluations: 93
# (2, 7) (2,) (2, 7) (2,)
# [8 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46.273222
#          Iterations: 4
#          Function evaluations: 114
#          Gradient evaluations: 102
# (2, 7) (2,) (2, 7) (2,)
# [5 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.036737
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (2, 7) (2,) (2, 7) (2,)
# [ 4 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.847346
#          Iterations: 5
#          Function evaluations: 116
#          Gradient evaluations: 104
# (2, 7) (2,) (2, 7) (2,)
# [5 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.687262
#          Iterations: 10
#          Function evaluations: 87
#          Gradient evaluations: 75
# (2, 7) (2,) (2, 7) (2,)
# [ 3 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52.418234
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 98
# (2, 7) (2,) (2, 7) (2,)
# [0 4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.279446
#          Iterations: 8
#          Function evaluations: 112
#          Gradient evaluations: 100
# (2, 7) (2,) (2, 7) (2,)
# [7 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 52.067648
#          Iterations: 5
#          Function evaluations: 108
#          Gradient evaluations: 96
# (2, 7) (2,) (2, 7) (2,)
# [7 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.421891
#          Iterations: 8
#          Function evaluations: 92
#          Gradient evaluations: 80
# (2, 7) (2,) (2, 7) (2,)
# [9 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55.923129
#          Iterations: 4
#          Function evaluations: 105
#          Gradient evaluations: 93
# (2, 7) (2,) (2, 7) (2,)
# [11  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 36.772823
#          Iterations: 5
#          Function evaluations: 109
#          Gradient evaluations: 97
# (2, 7) (2,) (2, 7) (2,)
# [1 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.668105
#          Iterations: 7
#          Function evaluations: 93
#          Gradient evaluations: 81
# (2, 7) (2,) (2, 7) (2,)
# [7 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.421891
#          Iterations: 8
#          Function evaluations: 92
#          Gradient evaluations: 80
# (2, 7) (2,) (2, 7) (2,)
# [2 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46.381302
#          Iterations: 5
#          Function evaluations: 114
#          Gradient evaluations: 102
# (2, 7) (2,) (2, 7) (2,)
# [10  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 47.168694
#          Iterations: 4
#          Function evaluations: 51
#          Gradient evaluations: 41
# (2, 7) (2,) (2, 7) (2,)
# [ 6 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.461270
#          Iterations: 3
#          Function evaluations: 115
#          Gradient evaluations: 103
# (2, 7) (2,) (2, 7) (2,)
# [5 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.036737
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (2, 7) (2,) (2, 7) (2,)
# [11  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 44.572221
#          Iterations: 3
#          Function evaluations: 101
#          Gradient evaluations: 89
# (2, 7) (2,) (2, 7) (2,)
# [ 9 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 7.096879
#          Iterations: 4
#          Function evaluations: 97
#          Gradient evaluations: 85
# (2, 7) (2,) (2, 7) (2,)
# [4 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 55.538475
#          Iterations: 4
#          Function evaluations: 88
#          Gradient evaluations: 76
# (2, 7) (2,) (2, 7) (2,)
# [0 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46.381302
#          Iterations: 5
#          Function evaluations: 114
#          Gradient evaluations: 102
# (2, 7) (2,) (2, 7) (2,)
# [2 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 46.381302
#          Iterations: 5
#          Function evaluations: 114
#          Gradient evaluations: 102
# (2, 7) (2,) (2, 7) (2,)
# [6 8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.317334
#          Iterations: 3
#          Function evaluations: 100
#          Gradient evaluations: 88
# (2, 7) (2,) (2, 7) (2,)
# [0 8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.663364
#          Iterations: 3
#          Function evaluations: 107
#          Gradient evaluations: 95
# (2, 7) (2,) (2, 7) (2,)
# [ 2 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 50.013645
#          Iterations: 2
#          Function evaluations: 112
#          Gradient evaluations: 100
# (2, 7) (2,) (2, 7) (2,)
# [1 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.668105
#          Iterations: 7
#          Function evaluations: 93
#          Gradient evaluations: 81
# (2, 7) (2,) (2, 7) (2,)
# [ 0 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.229384
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 98
# [ 0 10]
# (3, 7) (3,) (3, 7) (3,)
# [0 1 7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.882412
#          Iterations: 8
#          Function evaluations: 111
#          Gradient evaluations: 99
# (3, 7) (3,) (3, 7) (3,)
# [3 1 0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.531198
#          Iterations: 5
#          Function evaluations: 110
#          Gradient evaluations: 98
# (3, 7) (3,) (3, 7) (3,)
# [2 1 6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.668509
#          Iterations: 2
#          Function evaluations: 111
#          Gradient evaluations: 99
# (3, 7) (3,) (3, 7) (3,)
# [ 5  3 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.493070
#          Iterations: 5
#          Function evaluations: 109
#          Gradient evaluations: 97
# (3, 7) (3,) (3, 7) (3,)
# [1 3 7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.840060
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (3, 7) (3,) (3, 7) (3,)
# [6 3 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.536961
#          Iterations: 2
#          Function evaluations: 111
#          Gradient evaluations: 99
# (3, 7) (3,) (3, 7) (3,)
# [ 6 10  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.868962
#          Iterations: 4
#          Function evaluations: 99
#          Gradient evaluations: 87
# (3, 7) (3,) (3, 7) (3,)
# [8 2 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.840145
#          Iterations: 5
#          Function evaluations: 106
#          Gradient evaluations: 94
# (3, 7) (3,) (3, 7) (3,)
# [ 8  1 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.004513
#          Iterations: 3
#          Function evaluations: 109
#          Gradient evaluations: 97
# (3, 7) (3,) (3, 7) (3,)
# [11  0  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.439430
#          Iterations: 3
#          Function evaluations: 94
#          Gradient evaluations: 82
# (3, 7) (3,) (3, 7) (3,)
# [ 6  4 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.860214
#          Iterations: 5
#          Function evaluations: 109
#          Gradient evaluations: 97
# (3, 7) (3,) (3, 7) (3,)
# [8 1 6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.545544
#          Iterations: 3
#          Function evaluations: 101
#          Gradient evaluations: 89
# (3, 7) (3,) (3, 7) (3,)
# [ 0  8 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.616193
#          Iterations: 3
#          Function evaluations: 105
#          Gradient evaluations: 93
# (3, 7) (3,) (3, 7) (3,)
# [10 11  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.356421
#          Iterations: 2
#          Function evaluations: 109
#          Gradient evaluations: 97
# (3, 7) (3,) (3, 7) (3,)
# [10  9  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.757814
#          Iterations: 4
#          Function evaluations: 116
#          Gradient evaluations: 104
# (3, 7) (3,) (3, 7) (3,)
# [10  7  4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.885723
#          Iterations: 5
#          Function evaluations: 103
#          Gradient evaluations: 91
# (3, 7) (3,) (3, 7) (3,)
# [5 8 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.840145
#          Iterations: 5
#          Function evaluations: 110
#          Gradient evaluations: 98
# (3, 7) (3,) (3, 7) (3,)
# [4 3 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.217178
#          Iterations: 4
#          Function evaluations: 103
#          Gradient evaluations: 91
# (3, 7) (3,) (3, 7) (3,)
# [5 6 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.751096
#          Iterations: 4
#          Function evaluations: 102
#          Gradient evaluations: 90
# (3, 7) (3,) (3, 7) (3,)
# [3 2 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 38.405748
#          Iterations: 4
#          Function evaluations: 111
#          Gradient evaluations: 99
# (3, 7) (3,) (3, 7) (3,)
# [ 7  9 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.062099
#          Iterations: 5
#          Function evaluations: 116
#          Gradient evaluations: 104
# (3, 7) (3,) (3, 7) (3,)
# [ 4 10 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33.211840
#          Iterations: 4
#          Function evaluations: 113
#          Gradient evaluations: 101
# (3, 7) (3,) (3, 7) (3,)
# [7 4 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.000493
#          Iterations: 5
#          Function evaluations: 104
#          Gradient evaluations: 92
# (3, 7) (3,) (3, 7) (3,)
# [5 8 6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 15.007528
#          Iterations: 3
#          Function evaluations: 105
#          Gradient evaluations: 93
# (3, 7) (3,) (3, 7) (3,)
# [ 7 11  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 33.667672
#          Iterations: 3
#          Function evaluations: 107
#          Gradient evaluations: 95
# (3, 7) (3,) (3, 7) (3,)
# [10  8  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.431959
#          Iterations: 5
#          Function evaluations: 113
#          Gradient evaluations: 101
# (3, 7) (3,) (3, 7) (3,)
# [1 4 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.701534
#          Iterations: 10
#          Function evaluations: 104
#          Gradient evaluations: 92
# (3, 7) (3,) (3, 7) (3,)
# [1 0 6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.184988
#          Iterations: 3
#          Function evaluations: 98
#          Gradient evaluations: 86
# (3, 7) (3,) (3, 7) (3,)
# [ 6 11  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.648015
#          Iterations: 5
#          Function evaluations: 113
#          Gradient evaluations: 101
# (3, 7) (3,) (3, 7) (3,)
# [6 9 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.751096
#          Iterations: 4
#          Function evaluations: 98
#          Gradient evaluations: 86
# (3, 7) (3,) (3, 7) (3,)
# [10  2  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.501718
#          Iterations: 4
#          Function evaluations: 113
#          Gradient evaluations: 101
# (3, 7) (3,) (3, 7) (3,)
# [ 9 10  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 5.672675
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# (3, 7) (3,) (3, 7) (3,)
# [6 7 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.658462
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# (3, 7) (3,) (3, 7) (3,)
# [ 9 11  4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 31.989090
#          Iterations: 5
#          Function evaluations: 115
#          Gradient evaluations: 103
# (3, 7) (3,) (3, 7) (3,)
# [ 8 11  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.861542
#          Iterations: 3
#          Function evaluations: 96
#          Gradient evaluations: 84
# (3, 7) (3,) (3, 7) (3,)
# [8 2 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.840145
#          Iterations: 5
#          Function evaluations: 106
#          Gradient evaluations: 94
# (3, 7) (3,) (3, 7) (3,)
# [ 1  0 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.330625
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# (3, 7) (3,) (3, 7) (3,)
# [8 4 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.652735
#          Iterations: 10
#          Function evaluations: 86
#          Gradient evaluations: 74
# (3, 7) (3,) (3, 7) (3,)
# [ 6 10  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.860469
#          Iterations: 3
#          Function evaluations: 107
#          Gradient evaluations: 95
# (3, 7) (3,) (3, 7) (3,)
# [ 2 11  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 34.034690
#          Iterations: 2
#          Function evaluations: 111
#          Gradient evaluations: 99
# (3, 7) (3,) (3, 7) (3,)
# [0 6 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 14.032225
#          Iterations: 3
#          Function evaluations: 115
#          Gradient evaluations: 103
# (3, 7) (3,) (3, 7) (3,)
# [ 1 10  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.817065
#          Iterations: 3
#          Function evaluations: 44
#          Gradient evaluations: 33
# (3, 7) (3,) (3, 7) (3,)
# [10  1  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.383516
#          Iterations: 4
#          Function evaluations: 95
#          Gradient evaluations: 83
# (3, 7) (3,) (3, 7) (3,)
# [5 6 4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.638662
#          Iterations: 3
#          Function evaluations: 106
#          Gradient evaluations: 94
# (3, 7) (3,) (3, 7) (3,)
# [10  0  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.919235
#          Iterations: 3
#          Function evaluations: 50
#          Gradient evaluations: 39
# (3, 7) (3,) (3, 7) (3,)
# [0 4 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.848760
#          Iterations: 9
#          Function evaluations: 92
#          Gradient evaluations: 80
# (3, 7) (3,) (3, 7) (3,)
# [2 0 8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.802867
#          Iterations: 5
#          Function evaluations: 115
#          Gradient evaluations: 103
# (3, 7) (3,) (3, 7) (3,)
# [6 0 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.184988
#          Iterations: 3
#          Function evaluations: 93
#          Gradient evaluations: 81
# (3, 7) (3,) (3, 7) (3,)
# [11  0 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27.598493
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 96
# (3, 7) (3,) (3, 7) (3,)
# [ 5 11  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28.618590
#          Iterations: 3
#          Function evaluations: 89
#          Gradient evaluations: 77
# [ 5 11  0]
# (4, 7) (4,) (4, 7) (4,)
# [6 3 7 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.684708
#          Iterations: 3
#          Function evaluations: 104
#          Gradient evaluations: 92
# (4, 7) (4,) (4, 7) (4,)
# [ 1 10  0  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.673252
#          Iterations: 4
#          Function evaluations: 97
#          Gradient evaluations: 85
# (4, 7) (4,) (4, 7) (4,)
# [ 4  6  7 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.081564
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 96
# (4, 7) (4,) (4, 7) (4,)
# [4 7 8 5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.229756
#          Iterations: 11
#          Function evaluations: 96
#          Gradient evaluations: 84
# (4, 7) (4,) (4, 7) (4,)
# [ 0 11  5  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27.238061
#          Iterations: 4
#          Function evaluations: 51
#          Gradient evaluations: 39
# (4, 7) (4,) (4, 7) (4,)
# [ 1  4  2 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.942722
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# (4, 7) (4,) (4, 7) (4,)
# [ 2  5 10  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.839528
#          Iterations: 4
#          Function evaluations: 104
#          Gradient evaluations: 92
# (4, 7) (4,) (4, 7) (4,)
# [11  5  1  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27.238061
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 98
# (4, 7) (4,) (4, 7) (4,)
# [ 4  6 11  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 36.870399
#          Iterations: 4
#          Function evaluations: 94
#          Gradient evaluations: 82
# (4, 7) (4,) (4, 7) (4,)
# [ 5 11  8  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.333130
#          Iterations: 4
#          Function evaluations: 105
#          Gradient evaluations: 93
# (4, 7) (4,) (4, 7) (4,)
# [ 4 11  3  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 36.870399
#          Iterations: 4
#          Function evaluations: 112
#          Gradient evaluations: 100
# (4, 7) (4,) (4, 7) (4,)
# [10  8  6  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.547865
#          Iterations: 4
#          Function evaluations: 109
#          Gradient evaluations: 97
# (4, 7) (4,) (4, 7) (4,)
# [1 0 8 7]
# Optimization terminated successfully.
#          Current function value: 1.216244
#          Iterations: 13
#          Function evaluations: 14
#          Gradient evaluations: 14
# (4, 7) (4,) (4, 7) (4,)
# [5 3 2 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.625626
#          Iterations: 5
#          Function evaluations: 100
#          Gradient evaluations: 88
# (4, 7) (4,) (4, 7) (4,)
# [ 6  7  5 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.743101
#          Iterations: 3
#          Function evaluations: 89
#          Gradient evaluations: 77
# (4, 7) (4,) (4, 7) (4,)
# [4 1 5 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 0.773638
#          Iterations: 12
#          Function evaluations: 87
#          Gradient evaluations: 75
# (4, 7) (4,) (4, 7) (4,)
# [4 9 7 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.908407
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (4, 7) (4,) (4, 7) (4,)
# [10  2  1  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.650188
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (4, 7) (4,) (4, 7) (4,)
# [ 6  9  4 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.840781
#          Iterations: 6
#          Function evaluations: 120
#          Gradient evaluations: 108
# (4, 7) (4,) (4, 7) (4,)
# [ 5  8 11  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.532320
#          Iterations: 5
#          Function evaluations: 112
#          Gradient evaluations: 100
# (4, 7) (4,) (4, 7) (4,)
# [11  0  7  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.952394
#          Iterations: 3
#          Function evaluations: 102
#          Gradient evaluations: 90
# (4, 7) (4,) (4, 7) (4,)
# [ 7  5  8 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.079040
#          Iterations: 3
#          Function evaluations: 110
#          Gradient evaluations: 98
# (4, 7) (4,) (4, 7) (4,)
# [ 2 10  4 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 35.784051
#          Iterations: 4
#          Function evaluations: 105
#          Gradient evaluations: 93
# (4, 7) (4,) (4, 7) (4,)
# [ 5  6  1 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.833529
#          Iterations: 3
#          Function evaluations: 103
#          Gradient evaluations: 91
# (4, 7) (4,) (4, 7) (4,)
# [ 0  1 11  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.778354
#          Iterations: 3
#          Function evaluations: 102
#          Gradient evaluations: 90
# (4, 7) (4,) (4, 7) (4,)
# [ 3  0 10  4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27.324624
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# (4, 7) (4,) (4, 7) (4,)
# [ 4 11  9  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.253052
#          Iterations: 6
#          Function evaluations: 118
#          Gradient evaluations: 106
# (4, 7) (4,) (4, 7) (4,)
# [6 0 1 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.454769
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 98
# (4, 7) (4,) (4, 7) (4,)
# [10  3  5  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.877919
#          Iterations: 5
#          Function evaluations: 106
#          Gradient evaluations: 94
# (4, 7) (4,) (4, 7) (4,)
# [2 7 6 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.031198
#          Iterations: 3
#          Function evaluations: 113
#          Gradient evaluations: 101
# (4, 7) (4,) (4, 7) (4,)
# [7 8 9 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27.297278
#          Iterations: 5
#          Function evaluations: 104
#          Gradient evaluations: 92
# (4, 7) (4,) (4, 7) (4,)
# [10  1  3  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.629100
#          Iterations: 2
#          Function evaluations: 108
#          Gradient evaluations: 96
# (4, 7) (4,) (4, 7) (4,)
# [11  4  1 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.373766
#          Iterations: 4
#          Function evaluations: 54
#          Gradient evaluations: 43
# (4, 7) (4,) (4, 7) (4,)
# [11  1  5  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27.963736
#          Iterations: 2
#          Function evaluations: 108
#          Gradient evaluations: 96
# (4, 7) (4,) (4, 7) (4,)
# [ 0 10  7  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.334131
#          Iterations: 2
#          Function evaluations: 44
#          Gradient evaluations: 33
# (4, 7) (4,) (4, 7) (4,)
# [4 6 9 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 32.249251
#          Iterations: 4
#          Function evaluations: 101
#          Gradient evaluations: 89
# (4, 7) (4,) (4, 7) (4,)
# [3 9 0 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 26.875243
#          Iterations: 5
#          Function evaluations: 112
#          Gradient evaluations: 100
# (4, 7) (4,) (4, 7) (4,)
# [8 4 5 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.910645
#          Iterations: 4
#          Function evaluations: 105
#          Gradient evaluations: 93
# (4, 7) (4,) (4, 7) (4,)
# [4 3 1 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 27.515686
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# (4, 7) (4,) (4, 7) (4,)
# [11 10  9  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37.030039
#          Iterations: 5
#          Function evaluations: 104
#          Gradient evaluations: 92
# (4, 7) (4,) (4, 7) (4,)
# [1 3 4 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.960335
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# (4, 7) (4,) (4, 7) (4,)
# [ 8  6  5 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.336501
#          Iterations: 3
#          Function evaluations: 49
#          Gradient evaluations: 38
# (4, 7) (4,) (4, 7) (4,)
# [ 9  1 11  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 37.475165
#          Iterations: 5
#          Function evaluations: 106
#          Gradient evaluations: 94
# (4, 7) (4,) (4, 7) (4,)
# [8 0 9 7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 1.445813
#          Iterations: 13
#          Function evaluations: 107
#          Gradient evaluations: 95
# (4, 7) (4,) (4, 7) (4,)
# [11 10  9  4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.211129
#          Iterations: 5
#          Function evaluations: 111
#          Gradient evaluations: 99
# (4, 7) (4,) (4, 7) (4,)
# [0 6 4 7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 13.277429
#          Iterations: 3
#          Function evaluations: 111
#          Gradient evaluations: 99
# (4, 7) (4,) (4, 7) (4,)
# [10  9  5  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 4.331601
#          Iterations: 5
#          Function evaluations: 103
#          Gradient evaluations: 91
# (4, 7) (4,) (4, 7) (4,)
# [ 1  7 11  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28.981735
#          Iterations: 3
#          Function evaluations: 108
#          Gradient evaluations: 96
# (4, 7) (4,) (4, 7) (4,)
# [7 8 1 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.301454
#          Iterations: 4
#          Function evaluations: 95
#          Gradient evaluations: 83
# (4, 7) (4,) (4, 7) (4,)
# [5 0 3 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.831853
#          Iterations: 3
#          Function evaluations: 112
#          Gradient evaluations: 100
# [5 0 3 2]
# (5, 7) (5,) (5, 7) (5,)
# [11  1  0  7  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.282147
#          Iterations: 5
#          Function evaluations: 111
#          Gradient evaluations: 99
# (5, 7) (5,) (5, 7) (5,)
# [9 0 1 2 4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.362778
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# (5, 7) (5,) (5, 7) (5,)
# [ 0  7  8  5 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.932435
#          Iterations: 5
#          Function evaluations: 117
#          Gradient evaluations: 105
# (5, 7) (5,) (5, 7) (5,)
# [ 0  1  8 11 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.327000
#          Iterations: 4
#          Function evaluations: 103
#          Gradient evaluations: 91
# (5, 7) (5,) (5, 7) (5,)
# [10  3  0  8  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.294554
#          Iterations: 4
#          Function evaluations: 111
#          Gradient evaluations: 99
# (5, 7) (5,) (5, 7) (5,)
# [5 9 1 4 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.992085
#          Iterations: 4
#          Function evaluations: 98
#          Gradient evaluations: 86
# (5, 7) (5,) (5, 7) (5,)
# [11  6  9  8  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.255447
#          Iterations: 6
#          Function evaluations: 112
#          Gradient evaluations: 100
# (5, 7) (5,) (5, 7) (5,)
# [0 9 4 1 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.043465
#          Iterations: 4
#          Function evaluations: 103
#          Gradient evaluations: 91
# (5, 7) (5,) (5, 7) (5,)
# [9 1 7 2 8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.370277
#          Iterations: 5
#          Function evaluations: 104
#          Gradient evaluations: 92
# (5, 7) (5,) (5, 7) (5,)
# [0 5 1 3 6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.461393
#          Iterations: 4
#          Function evaluations: 114
#          Gradient evaluations: 102
# (5, 7) (5,) (5, 7) (5,)
# [ 5 10  7  9  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.078779
#          Iterations: 6
#          Function evaluations: 108
#          Gradient evaluations: 96
# (5, 7) (5,) (5, 7) (5,)
# [ 1  8  6  4 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 10.695692
#          Iterations: 5
#          Function evaluations: 59
#          Gradient evaluations: 47
# (5, 7) (5,) (5, 7) (5,)
# [ 1  8  9 10  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.445889
#          Iterations: 5
#          Function evaluations: 111
#          Gradient evaluations: 99
# (5, 7) (5,) (5, 7) (5,)
# [ 1  2 10  8  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 18.095529
#          Iterations: 4
#          Function evaluations: 113
#          Gradient evaluations: 101
# (5, 7) (5,) (5, 7) (5,)
# [8 6 1 9 2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.640700
#          Iterations: 7
#          Function evaluations: 103
#          Gradient evaluations: 91
# (5, 7) (5,) (5, 7) (5,)
# [ 5  8 11  4  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.719093
#          Iterations: 7
#          Function evaluations: 112
#          Gradient evaluations: 100
# (5, 7) (5,) (5, 7) (5,)
# [ 0 10  5  4  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.122402
#          Iterations: 4
#          Function evaluations: 98
#          Gradient evaluations: 86
# (5, 7) (5,) (5, 7) (5,)
# [ 4  3 10  6  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 25.297120
#          Iterations: 4
#          Function evaluations: 98
#          Gradient evaluations: 86
# (5, 7) (5,) (5, 7) (5,)
# [8 2 9 7 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.370277
#          Iterations: 5
#          Function evaluations: 105
#          Gradient evaluations: 93
# (5, 7) (5,) (5, 7) (5,)
# [ 4  9  2 11  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.098865
#          Iterations: 4
#          Function evaluations: 105
#          Gradient evaluations: 93
# (5, 7) (5,) (5, 7) (5,)
# [ 9  3  8 10 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.176178
#          Iterations: 6
#          Function evaluations: 113
#          Gradient evaluations: 101
# (5, 7) (5,) (5, 7) (5,)
# [ 2 10  4  0  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.753514
#          Iterations: 4
#          Function evaluations: 108
#          Gradient evaluations: 96
# (5, 7) (5,) (5, 7) (5,)
# [7 6 3 0 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.451758
#          Iterations: 3
#          Function evaluations: 105
#          Gradient evaluations: 93
# (5, 7) (5,) (5, 7) (5,)
# [11  1  2  6  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.514016
#          Iterations: 2
#          Function evaluations: 111
#          Gradient evaluations: 99
# (5, 7) (5,) (5, 7) (5,)
# [10  0  2  7  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.133718
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# (5, 7) (5,) (5, 7) (5,)
# [ 8  6  1 11  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 20.468089
#          Iterations: 4
#          Function evaluations: 49
#          Gradient evaluations: 37
# (5, 7) (5,) (5, 7) (5,)
# [ 2  3  9  7 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 30.082067
#          Iterations: 5
#          Function evaluations: 101
#          Gradient evaluations: 89
# (5, 7) (5,) (5, 7) (5,)
# [5 6 0 1 9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 11.549761
#          Iterations: 5
#          Function evaluations: 58
#          Gradient evaluations: 47
# (5, 7) (5,) (5, 7) (5,)
# [ 9 11  7  5  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28.660824
#          Iterations: 6
#          Function evaluations: 103
#          Gradient evaluations: 91
# (5, 7) (5,) (5, 7) (5,)
# [ 7 10 11  3  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.375612
#          Iterations: 2
#          Function evaluations: 110
#          Gradient evaluations: 98
# (5, 7) (5,) (5, 7) (5,)
# [4 5 9 7 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 21.281076
#          Iterations: 4
#          Function evaluations: 93
#          Gradient evaluations: 81
# (5, 7) (5,) (5, 7) (5,)
# [ 2 10  5  6  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.414240
#          Iterations: 3
#          Function evaluations: 98
#          Gradient evaluations: 86
# (5, 7) (5,) (5, 7) (5,)
# [10  5  7  0  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 2.941469
#          Iterations: 4
#          Function evaluations: 47
#          Gradient evaluations: 35
# (5, 7) (5,) (5, 7) (5,)
# [ 7  9  2 10  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.226741
#          Iterations: 5
#          Function evaluations: 99
#          Gradient evaluations: 87
# (5, 7) (5,) (5, 7) (5,)
# [3 2 0 5 4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.323791
#          Iterations: 5
#          Function evaluations: 108
#          Gradient evaluations: 96
# (5, 7) (5,) (5, 7) (5,)
# [ 9 10  0  8  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 3.433085
#          Iterations: 5
#          Function evaluations: 96
#          Gradient evaluations: 84
# (5, 7) (5,) (5, 7) (5,)
# [10  6 11  3  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.006308
#          Iterations: 4
#          Function evaluations: 106
#          Gradient evaluations: 94
# (5, 7) (5,) (5, 7) (5,)
# [ 7  3  4  0 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28.561918
#          Iterations: 7
#          Function evaluations: 56
#          Gradient evaluations: 44
# (5, 7) (5,) (5, 7) (5,)
# [0 7 8 3 1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.925356
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (5, 7) (5,) (5, 7) (5,)
# [ 4  5  9 10  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.103246
#          Iterations: 4
#          Function evaluations: 110
#          Gradient evaluations: 98
# (5, 7) (5,) (5, 7) (5,)
# [ 9 11  2  5  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 29.414066
#          Iterations: 7
#          Function evaluations: 100
#          Gradient evaluations: 88
# (5, 7) (5,) (5, 7) (5,)
# [9 6 5 3 8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 24.942942
#          Iterations: 7
#          Function evaluations: 91
#          Gradient evaluations: 79
# (5, 7) (5,) (5, 7) (5,)
# [5 4 3 0 6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.981134
#          Iterations: 4
#          Function evaluations: 107
#          Gradient evaluations: 95
# (5, 7) (5,) (5, 7) (5,)
# [ 7  4  6 11  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 19.857192
#          Iterations: 5
#          Function evaluations: 113
#          Gradient evaluations: 101
# (5, 7) (5,) (5, 7) (5,)
# [ 9 11  7  8  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.190053
#          Iterations: 5
#          Function evaluations: 101
#          Gradient evaluations: 89
# (5, 7) (5,) (5, 7) (5,)
# [5 4 6 0 3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.981134
#          Iterations: 4
#          Function evaluations: 112
#          Gradient evaluations: 100
# (5, 7) (5,) (5, 7) (5,)
# [ 2  4  7 11  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 28.501605
#          Iterations: 4
#          Function evaluations: 106
#          Gradient evaluations: 94
# (5, 7) (5,) (5, 7) (5,)
# [ 8  5  2  3 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 22.937824
#          Iterations: 3
#          Function evaluations: 107
#          Gradient evaluations: 95
# (5, 7) (5,) (5, 7) (5,)
# [ 4  1 10  2  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 23.809387
#          Iterations: 6
#          Function evaluations: 100
#          Gradient evaluations: 88
# (5, 7) (5,) (5, 7) (5,)
# [0 3 7 4 8]
# ...
#          Iterations: 17
#          Function evaluations: 101
#          Gradient evaluations: 89
# (12, 7) (12,) (12, 7) (12,)
# [ 0  8  3  1  4  5  7 10  6  9  2 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 111
#          Gradient evaluations: 99
# (12, 7) (12,) (12, 7) (12,)
# [11  1  7  5  2  4  8  9 10  6  3  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 97
#          Gradient evaluations: 85
# (12, 7) (12,) (12, 7) (12,)
# [ 7  5 11 10  9  0  1  6  3  2  4  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 98
#          Gradient evaluations: 86
# (12, 7) (12,) (12, 7) (12,)
# [ 1 10  0 11  4  3  7  2  9  5  8  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 101
#          Gradient evaluations: 89
# (12, 7) (12,) (12, 7) (12,)
# [ 3  9  8  6  4 11  5  7  2  1  0 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 88
#          Gradient evaluations: 76
# (12, 7) (12,) (12, 7) (12,)
# [ 1  3  8  2  5 11  4  7  9  0  6 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 103
#          Gradient evaluations: 91
# (12, 7) (12,) (12, 7) (12,)
# [ 6  9  5 11  1  4  7 10  8  3  2  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 111
#          Gradient evaluations: 99
# (12, 7) (12,) (12, 7) (12,)
# [10  3 11  9  0  1  5  2  7  6  8  4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 90
#          Gradient evaluations: 78
# [10  3 11  9  0  1  5  2  7  6  8  4]
# (12, 7) (12,) (12, 7) (12,)
# [ 8  3 11  1  0  5  2  4  7  9  6 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 111
#          Gradient evaluations: 99
# (12, 7) (12,) (12, 7) (12,)
# [ 3  8 10  6  2  5  0  9 11  7  4  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 110
#          Gradient evaluations: 98
# (12, 7) (12,) (12, 7) (12,)
# [ 3  8  5 10  0  7  2  1  4 11  9  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 106
#          Gradient evaluations: 94
# (12, 7) (12,) (12, 7) (12,)
# [ 0  8  4  5  1  3  2  6 11  7 10  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 110
#          Gradient evaluations: 98
# (12, 7) (12,) (12, 7) (12,)
# [ 0  4  6  2  9  1  8 10 11  5  7  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 108
#          Gradient evaluations: 96
# (12, 7) (12,) (12, 7) (12,)
# [ 0 10  4  2  8  7  9  5  6  3 11  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 107
#          Gradient evaluations: 95
# (12, 7) (12,) (12, 7) (12,)
# [ 3  7  8  1 11  5  9  0  4  2 10  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 101
#          Gradient evaluations: 89
# (12, 7) (12,) (12, 7) (12,)
# [ 5  4  0  3  2  8  6  1 10  9 11  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 99
#          Gradient evaluations: 87
# (12, 7) (12,) (12, 7) (12,)
# [ 0  1 11  4  8  2  6  5  3  7  9 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 104
#          Gradient evaluations: 92
# (12, 7) (12,) (12, 7) (12,)
# [ 4  8  1  3  7 10 11  2  6  0  9  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 102
#          Gradient evaluations: 90
# (12, 7) (12,) (12, 7) (12,)
# [ 1  7  9  5  3  6  2 11  0 10  8  4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 87
#          Gradient evaluations: 75
# (12, 7) (12,) (12, 7) (12,)
# [ 9  3  0  4  5  2 10  6 11  8  1  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 100
#          Gradient evaluations: 88
# (12, 7) (12,) (12, 7) (12,)
# [ 5  2  0  1  9 11  8  3 10  6  4  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 107
#          Gradient evaluations: 95
# (12, 7) (12,) (12, 7) (12,)
# [10  4  3  2  6  1  7  9  5 11  8  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 118
#          Gradient evaluations: 106
# (12, 7) (12,) (12, 7) (12,)
# [10  1 11  5  2  3  9  0  6  8  4  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 113
#          Gradient evaluations: 101
# (12, 7) (12,) (12, 7) (12,)
# [ 1  4  6 10  3  0  2  5  8  7 11  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 98
#          Gradient evaluations: 86
# (12, 7) (12,) (12, 7) (12,)
# [ 2  6  4  8  7  5 11 10  0  3  9  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 116
#          Gradient evaluations: 104
# (12, 7) (12,) (12, 7) (12,)
# [ 4  6  8 11  7  3  2  9 10  1  5  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 95
#          Gradient evaluations: 83
# (12, 7) (12,) (12, 7) (12,)
# [ 5  9  3  7  6  0 11 10  2  8  4  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 95
#          Gradient evaluations: 83
# (12, 7) (12,) (12, 7) (12,)
# [ 0  5  2  6  7  9  1 11  3  4 10  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 93
#          Gradient evaluations: 81
# (12, 7) (12,) (12, 7) (12,)
# [ 6 11  3  9  2  5  1  7  4  0  8 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 94
#          Gradient evaluations: 82
# (12, 7) (12,) (12, 7) (12,)
# [ 9  3  4  8 11  2  0  7  1 10  5  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 94
#          Gradient evaluations: 82
# (12, 7) (12,) (12, 7) (12,)
# [10  1  3  5  8  6  4  2 11  7  9  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 117
#          Gradient evaluations: 105
# (12, 7) (12,) (12, 7) (12,)
# [ 8  2  1  9  6  0 11 10  4  7  5  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 102
#          Gradient evaluations: 90
# (12, 7) (12,) (12, 7) (12,)
# [ 8 11 10  0  6  5  3  9  2  4  1  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 97
#          Gradient evaluations: 85
# (12, 7) (12,) (12, 7) (12,)
# [ 1  3  0  5 10  7  2  4  9 11  6  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 105
#          Gradient evaluations: 93
# (12, 7) (12,) (12, 7) (12,)
# [10  9  4  5  8  2  1  6  3  7 11  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 101
#          Gradient evaluations: 89
# (12, 7) (12,) (12, 7) (12,)
# [ 3 10  5  9  8 11  4  6  2  1  0  7]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 102
#          Gradient evaluations: 90
# (12, 7) (12,) (12, 7) (12,)
# [ 7  3  9 10  0  2  6  8  1 11  4  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 90
#          Gradient evaluations: 78
# (12, 7) (12,) (12, 7) (12,)
# [ 0  9 11  4  6  7  2  5  1  8  3 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 105
#          Gradient evaluations: 93
# (12, 7) (12,) (12, 7) (12,)
# [ 0 11  7  1  6  2 10  9  3  4  8  5]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 104
#          Gradient evaluations: 92
# (12, 7) (12,) (12, 7) (12,)
# [11  0  8  1  9  7  5 10  2  4  3  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 105
#          Gradient evaluations: 93
# (12, 7) (12,) (12, 7) (12,)
# [ 5  7  4  2  1  8  3  9  0 10 11  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 113
#          Gradient evaluations: 101
# (12, 7) (12,) (12, 7) (12,)
# [10  0  6  3  9  1  7  8  4  5  2 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 116
#          Gradient evaluations: 104
# (12, 7) (12,) (12, 7) (12,)
# [ 5  7 11  3  0  4 10  9  1  8  2  6]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 103
#          Gradient evaluations: 91
# (12, 7) (12,) (12, 7) (12,)
# [ 1  4 10  6  7  9  8 11  2  3  5  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 113
#          Gradient evaluations: 101
# (12, 7) (12,) (12, 7) (12,)
# [ 8  5  3  7  9 11  0  4  1  2  6 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 100
#          Gradient evaluations: 88
# (12, 7) (12,) (12, 7) (12,)
# [ 2  9  6  5  7 11  8  1 10  0  4  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 105
#          Gradient evaluations: 93
# (12, 7) (12,) (12, 7) (12,)
# [ 4  8  0  5  3 10  6  1 11  7  9  2]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 100
#          Gradient evaluations: 88
# (12, 7) (12,) (12, 7) (12,)
# [ 3  7  6  8 10  0  5 11  1  4  2  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 109
#          Gradient evaluations: 97
# (12, 7) (12,) (12, 7) (12,)
# [ 0  7  8  6 10  5  3  2  1  9  4 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 112
#          Gradient evaluations: 100
# (12, 7) (12,) (12, 7) (12,)
# [ 0  3  2  8 10 11  7  5  6  1  4  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 97
#          Gradient evaluations: 85
# (12, 7) (12,) (12, 7) (12,)
# [11  5 10  6  8  0  9  4  1  7  2  3]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 115
#          Gradient evaluations: 103
# (12, 7) (12,) (12, 7) (12,)
# [ 9  8 10  5  2  0  6  7  3  1 11  4]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 115
#          Gradient evaluations: 103
# (12, 7) (12,) (12, 7) (12,)
# [ 3  6  2  7  8  0  4  5 10  1  9 11]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 97
#          Gradient evaluations: 85
# (12, 7) (12,) (12, 7) (12,)
# [11  0  6  2  3  7 10  1  4  5  8  9]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 113
#          Gradient evaluations: 101
# (12, 7) (12,) (12, 7) (12,)
# [ 5  9  7  2  0 11 10  3  4  1  6  8]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 82
#          Gradient evaluations: 70
# (12, 7) (12,) (12, 7) (12,)
# [ 1  3  5 10 11  6  7  4  9  2  8  0]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 95
#          Gradient evaluations: 83
# (12, 7) (12,) (12, 7) (12,)
# [ 9  3 11  6  5  8  4 10  7  0  2  1]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 107
#          Gradient evaluations: 95
# (12, 7) (12,) (12, 7) (12,)
# [11  4  7  0  5  9  2  8  3  6  1 10]
# Warning: Desired error not necessarily achieved due to precision loss.
#          Current function value: 12.133902
#          Iterations: 17
#          Function evaluations: 100
#          Gradient evaluations: 88
# [11  4  7  0  5  9  2  8  3  6  1 10]

# %% [markdown]
# ## Extra Credit: Building regularized models for Boston data set
# Perform a bias variance analysis of the Boston housing data set with the thirteen predictors, following the steps on the simple data set above. Use sklearn's  built-in functions to split the data into training, validation and test sets. What is the lowest achievable error on the test set with $\lambda = 0$? Select the best value for $\lambda$ and report the test set error with the best $\lambda$. Use the technique of adding features to extend each column of the Boston data set with powers of the values in the column. Repeat the bias-variance analysis with quadratic and cubic features. What is the test set error with quadratic features with the best $\lambda$ chosen with the validation set? What is the test set error with cubic features with the best $\lambda$ chosen with the validation set? Put your analysis code in a separate Python script or notebook called bostonexpt.py or bostonexpt.ipynb. Present your results analytically with plots to support your findings. Discuss the impact of regularization for building good models for the Boston housing data set.

# %%
### TODO: your Boston code here or in a separate notebook.
